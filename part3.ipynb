# %% [markdown]
# # Part 3 Visualized
# This is just here so I don't need to copy this table into the pdf
#
# ## LLM Dataset

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None) 
pd.set_option('display.width', None) # set these so that it doesnt cut off the long text

# %%
LLM_df = pd.read_json("LLM_data_sample_10.json")
# gonna drop some irrelevant columns

LLM_df = LLM_df[['is_correct','question','generated_solution','quality_assessment']]

LLM_df
# Out:
#    is_correct  \
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    question  \
# ...

# %% [markdown]
# ## Breast Cancer Dataset

# %%
b_df = pd.read_json("breast_cancer_sample_10.json")
# gonna drop a bunch of columns just for visualization, the ones that aren't shown are still important
b_df = b_df[["diagnosis"
    ,"radius_mean"
    ,"texture_mean"
    ,"perimeter_mean" 
    ,"quality_assessment"]]

b_df
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0         B        11.32         27.08           71.76
# 1         M        11.42         20.38           77.58
# 2         B        11.67         20.02           75.21
# 3         M        19.55         23.21          128.90
# 4         M        15.46         19.48          101.70
# 5         B        15.73         11.28          102.80
# 6         B        12.21         18.02           78.31
# 7         B        13.03         18.42           82.61
# 8         B        11.36         17.57           72.49
# 9         M        18.08         21.84          117.40
#
# ...
